# %%
import pandas as pd 
import numpy as np 
import keras 
from keras.models import Sequential
from keras.layers import Dense, Input
from keras.utils import to_categorical
import matplotlib.pyplot as plt 
from keras.datasets import mnist

# %%
## load the data into its variables 

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
# flatten images into one-dimensional vector

num_pixels = x_train.shape[1] * x_train.shape[2] # find size of one-dimensional vector

x_train = x_train.reshape(x_train.shape[0], num_pixels).astype('float32') # flatten training images
x_test = x_test.reshape(x_test.shape[0], num_pixels).astype('float32') # flatten test images

# %%
## then we're going to normalize the data 
x_train = x_train/255
x_test = x_test /255

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1]
print(num_classes)
# Out:
# 10

# %%
def classification_model():
    model = Sequential()

    model.add(Dense(num_pixels, activation="relu", input_shape=(num_pixels,)))
    model.add(Dense(100, activation="relu"))
    model.add(Dense(num_classes, activation="softmax"))

    model.compile(optimizer = "adam", loss = "categorical_crossentropy", metrics = ["accuracy"])
    return model

# %%
model = classification_model()

model.fit(x_train, y_train, validation_data=(x_test , y_test), epochs = 10, verbose = 2)

scores = model.evaluate(x_test,y_test, verbose = 0)
scores
# Out:
# Epoch 1/10
# 1875/1875 - 18s - 10ms/step - accuracy: 0.9427 - loss: 0.1871 - val_accuracy: 0.9687 - val_loss: 0.1023
# Epoch 2/10
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9754 - loss: 0.0787 - val_accuracy: 0.9671 - val_loss: 0.1090
# Epoch 3/10
# 1875/1875 - 16s - 9ms/step - accuracy: 0.9829 - loss: 0.0533 - val_accuracy: 0.9790 - val_loss: 0.0722
# Epoch 4/10
# 1875/1875 - 20s - 11ms/step - accuracy: 0.9879 - loss: 0.0379 - val_accuracy: 0.9788 - val_loss: 0.0750
# Epoch 5/10
# 1875/1875 - 16s - 9ms/step - accuracy: 0.9903 - loss: 0.0308 - val_accuracy: 0.9749 - val_loss: 0.0906
# Epoch 6/10
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9913 - loss: 0.0267 - val_accuracy: 0.9799 - val_loss: 0.0756
# Epoch 7/10
# 1875/1875 - 16s - 9ms/step - accuracy: 0.9924 - loss: 0.0225 - val_accuracy: 0.9815 - val_loss: 0.0740
# Epoch 8/10
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9937 - loss: 0.0202 - val_accuracy: 0.9804 - val_loss: 0.0829
# Epoch 9/10
# 1875/1875 - 15s - 8ms/step - accuracy: 0.9947 - loss: 0.0167 - val_accuracy: 0.9799 - val_loss: 0.0891
# Epoch 10/10
# 1875/1875 - 16s - 9ms/step - accuracy: 0.9950 - loss: 0.0156 - val_accuracy: 0.9815 - val_loss: 0.0881
# [0.0881052166223526, 0.9815000295639038]
